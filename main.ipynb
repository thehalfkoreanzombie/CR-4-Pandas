# %% [markdown]
# Use the pandas `.read_csv()` method to assign the contents of the Spotify dataset to a variable called `songs`.
#
# Use `head()` to show the first five rows of `songs`.

# %%
import pandas as pd

songs = pd.read_csv("./data/dataset.csv", header=0)
songs.head(5)
# Out:
#    Unnamed: 0                track_id                 artists  \
# 0           0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1           1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2           2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3           3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4           4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
#
#                                           album_name  \
# 0                                             Comedy
# 1                                   Ghost (Acoustic)
# 2                                     To Begin Again
# 3  Crazy Rich Asians (Original Motion Picture Sou...
# 4                                            Hold On
#
#                    track_name  popularity  duration_ms  explicit  \
# 0                      Comedy          73       230666     False
# 1            Ghost - Acoustic          55       149610     False
# 2              To Begin Again          57       210826     False
# 3  Can't Help Falling In Love          71       201933     False
# 4                     Hold On          82       198853     False
#
#    danceability  energy  ...  loudness  mode  speechiness  acousticness  \
# 0         0.676  0.4610  ...    -6.746     0       0.1430        0.0322
# 1         0.420  0.1660  ...   -17.235     1       0.0763        0.9240
# 2         0.438  0.3590  ...    -9.734     1       0.0557        0.2100
# 3         0.266  0.0596  ...   -18.515     1       0.0363        0.9050
# 4         0.618  0.4430  ...    -9.681     1       0.0526        0.4690
#
#    instrumentalness  liveness  valence    tempo  time_signature  track_genre
# 0          0.000001    0.3580    0.715   87.917               4     acoustic
# 1          0.000006    0.1010    0.267   77.489               4     acoustic
# 2          0.000000    0.1170    0.120   76.332               4     acoustic
# 3          0.000071    0.1320    0.143  181.740               3     acoustic
# 4          0.000000    0.0829    0.167  119.949               4     acoustic
#
# [5 rows x 21 columns]

# %% [markdown]
# This dataset includes a column called ‘duration_ms’ that has a string of each track’s length in milliseconds.
# Convert the values in the ‘duration_ms’ column from strings to integers.
# Convert from milliseconds to minutes, by dividing each value by 60000.
# Use `.rename()` to change the name of the 'duration_ms' column to  'minutes_long'.

# %%
def ms_apply(num):
    try:
        ms_to_minutes = num / 60000
        string_minutes = str(ms_to_minutes)
        return string_minutes

    except:
        return num
songs["duration_ms"] = songs["duration_ms"].map(ms_apply)
songs = songs.rename(columns={'duration_ms':'minutes_long'})
#print(songs.dtypes)
songs.head(5)
# Out:
#    Unnamed: 0                track_id                 artists  \
# 0           0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1           1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2           2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3           3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4           4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
#
#                                           album_name  \
# 0                                             Comedy
# 1                                   Ghost (Acoustic)
# 2                                     To Begin Again
# 3  Crazy Rich Asians (Original Motion Picture Sou...
# 4                                            Hold On
#
#                    track_name  popularity        minutes_long  explicit  \
# 0                      Comedy          73  3.8444333333333334     False
# 1            Ghost - Acoustic          55              2.4935     False
# 2              To Begin Again          57  3.5137666666666667     False
# 3  Can't Help Falling In Love          71             3.36555     False
# 4                     Hold On          82   3.314216666666667     False
#
#    danceability  energy  ...  loudness  mode  speechiness  acousticness  \
# 0         0.676  0.4610  ...    -6.746     0       0.1430        0.0322
# 1         0.420  0.1660  ...   -17.235     1       0.0763        0.9240
# 2         0.438  0.3590  ...    -9.734     1       0.0557        0.2100
# 3         0.266  0.0596  ...   -18.515     1       0.0363        0.9050
# 4         0.618  0.4430  ...    -9.681     1       0.0526        0.4690
#
#    instrumentalness  liveness  valence    tempo  time_signature  track_genre
# 0          0.000001    0.3580    0.715   87.917               4     acoustic
# 1          0.000006    0.1010    0.267   77.489               4     acoustic
# 2          0.000000    0.1170    0.120   76.332               4     acoustic
# 3          0.000071    0.1320    0.143  181.740               3     acoustic
# 4          0.000000    0.0829    0.167  119.949               4     acoustic
#
# [5 rows x 21 columns]

# %% [markdown]
# Use `.count()` to show how many times ‘FKA twigs’ is a value in the ‘artists’ column.

# %%
fka_twigs = songs.loc[songs.artists == 'FKA twigs']
print(fka_twigs.count())
#print(fka_twigs)
# Out:
# Unnamed: 0          50
# track_id            50
# artists             50
# album_name          50
# track_name          50
# popularity          50
# minutes_long        50
# explicit            50
# danceability        50
# energy              50
# key                 50
# loudness            50
# mode                50
# speechiness         50
# acousticness        50
# instrumentalness    50
# liveness            50
# valence             50
# tempo               50
# time_signature      50
# track_genre         50
# dtype: int64

# %% [markdown]
# Use `.groupby()` to get the max ‘danceability’ rating for each track_genre.
# Notice that ‘danceability’ and ‘track_genre’ are both columns in the dataset.

# %%
#track_genre_unique = songs.track_genre.unique()
#len(track_genre_unique)
max_dance_per_genre = songs.groupby('track_genre').danceability.max()
max_dance_per_genre
# Out:
# track_genre
# acoustic       0.879
# afrobeat       0.974
# alt-rock       0.922
# alternative    0.969
# ambient        0.853
#                ...
# techno         0.952
# trance         0.899
# trip-hop       0.985
# turkish        0.966
# world-music    0.838
# Name: danceability, Length: 114, dtype: float64
